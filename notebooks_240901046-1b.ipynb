# %%
#1b
#system of linear equation
import numpy as np

A = np.array([[2,3],
              [1,2]])

b = np.array([5,3])

x = np.linalg.solve(A,b)

print("Solution x =", x)
# Out:
# Solution x = [1. 1.]
