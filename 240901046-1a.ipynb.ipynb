# %%
import random

# Generate 20 random student scores out of 100
scores = [random.randint(30, 100) for _ in range(20)]
pass_mark = 50

# 1. Overall class performance
average_score = sum(scores) / len(scores)
highest_score = max(scores)
lowest_score = min(scores)

print(f"Scores: {scores}")
print(f"Average: {average_score:.2f}, Highest: {highest_score}, Lowest: {lowest_score}")

# 2. Pass/fail classification & 3. Grading on a curve
results = []
for score in scores:
    status = "Pass" if score >= pass_mark else "Fail"
    
    # Predefined thresholds for grades
    if score >= 90: grade = 'A'
    elif score >= 80: grade = 'B'
    elif score >= 70: grade = 'C'
    elif score >= 60: grade = 'D'
    else: grade = 'F'
    
    results.append((score, status, grade))

print("\nStudent Results (Score, Status, Grade):")
for res in results:
    print(res)
# Out:
# Scores: [82, 43, 61, 90, 74, 78, 55, 81, 100, 97, 95, 92, 73, 98, 71, 81, 79, 61, 65, 33]
# Average: 75.45, Highest: 100, Lowest: 33
#
# Student Results (Score, Status, Grade):
# (82, 'Pass', 'B')
# (43, 'Fail', 'F')
# (61, 'Pass', 'D')
# (90, 'Pass', 'A')
# (74, 'Pass', 'C')
# (78, 'Pass', 'C')
# (55, 'Pass', 'F')
# (81, 'Pass', 'B')
# (100, 'Pass', 'A')
# (97, 'Pass', 'A')
# (95, 'Pass', 'A')
# (92, 'Pass', 'A')
# (73, 'Pass', 'C')
# (98, 'Pass', 'A')
# (71, 'Pass', 'C')
# (81, 'Pass', 'B')
# (79, 'Pass', 'C')
# (61, 'Pass', 'D')
# (65, 'Pass', 'D')
# (33, 'Fail', 'F')
